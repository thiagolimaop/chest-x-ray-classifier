# %% [markdown]
# # Experiment IV
#
# This fourth experiment will try to increase the test accuracy apply brightness augmentation.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Importing packages
#
# Let's start by importing required packages:
#
# * os — to read files and directory structure
# * numpy — for some matrix math outside of TensorFlow
# * matplotlib.pyplot — to plot the graph and display images in our training and validation data

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# # Data Loading
#
# To build our image classifier, we begin by unzipping the dataset.

# %%
root_path = '/content/drive/MyDrive/DataSets'
os.chdir(root_path)

# %% [markdown]
# We can list the directories with the following terminal command:

# %%
dir = '/content/drive/MyDrive/DataSets/chest_xray'
zip_dir_base = os.path.dirname(dir)
# !find $zip_dir_base -type d -print
# Out:
# /content/drive/MyDrive/DataSets
# /content/drive/MyDrive/DataSets/chest_xray
# /content/drive/MyDrive/DataSets/chest_xray/test
# /content/drive/MyDrive/DataSets/chest_xray/test/PNEUMONIA
# /content/drive/MyDrive/DataSets/chest_xray/test/NORMAL
# /content/drive/MyDrive/DataSets/chest_xray/train
# /content/drive/MyDrive/DataSets/chest_xray/train/NORMAL
# /content/drive/MyDrive/DataSets/chest_xray/train/PNEUMONIA
# /content/drive/MyDrive/DataSets/chest_xray/val
# /content/drive/MyDrive/DataSets/chest_xray/val/NORMAL
# /content/drive/MyDrive/DataSets/chest_xray/val/PNEUMONIA
# /content/drive/MyDrive/DataSets/__MACOSX
# /content/drive/MyDrive/DataSets/__MACOSX/chest_xray
# /content/drive/MyDrive/DataSets/__MACOSX/chest_xray/test
# /content/drive/MyDrive/DataSets/__MACOSX/chest_xray/test/PNEUMONIA
# /content/drive/MyDrive/DataSets/__MACOSX/chest_xray/train
# /content/drive/MyDrive/DataSets/__MACOSX/chest_xray/train/PNEUMONIA
# /content/drive/MyDrive/DataSets/__MACOSX/chest_xray/train/NORMAL

# %% [markdown]
# We'll now assign variables with the proper file path for the training and test sets.

# %%
base_dir = os.path.join(os.path.dirname(dir), 'chest_xray')
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')
val_dir = os.path.join(base_dir, 'val')

# %% [markdown]
# Let's look at how many normal and pneumonia images we have in our training, validation and test directory.

# %%
def get_total_chest_xray(category, source):
  """
  INPUT
  category: data set category, which could be 'training', 'test' and 'validation'
  source: a directory path.

  OUTPUT
  num_normal: total number of pictures
  num_pneumonia: 
  total: 

  DESCRIPTION
  This function move X (amount) random pictures from a source folder
  to destination folder.
  """
  source_normal = os.path.join(source, 'NORMAL') 
  source_pneumonia = os.path.join(source, 'PNEUMONIA')

  num_normal = len(os.listdir(source_normal))
  num_pneumonia = len(os.listdir(source_pneumonia))
  total = num_normal + num_pneumonia

  print('Total {}: {}'.format(category, total))
  print('total {} normal images: {}'.format(category, num_normal))
  print('total {} pneumonia images: {}'.format(category, num_pneumonia))

  return num_normal, num_pneumonia, total

# %%
num_normal_tr, num_pneumonia_tr, total_train = get_total_chest_xray('training', train_dir)
# Out:
# Total training: 3515
# total training normal images: 979
# total training pneumonia images: 2536

# %%
num_normal_test, num_pneumonia_test, total_test = get_total_chest_xray('test', test_dir)
# Out:
# Total test: 1171
# total test normal images: 302
# total test pneumonia images: 869

# %%
num_normal_val, num_pneumonia_val, total_val = get_total_chest_xray('validation', val_dir)
# Out:
# Total validation: 1171
# total validation normal images: 302
# total validation pneumonia images: 869

# %% [markdown]
# ## Setting Model Parameters
#
# Let's specify some model parameters.

# %%
BATCH_SIZE = 100  # Specifies how many training examples we feed our model before we update it's weight and bias variables
IMG_SHAPE  = 150  # Specifies the width and height in pixels to help the model process the images using a single input size

# %% [markdown]
# # Data Augmentation
#
#
# We will apply rotation to our training set to augment the dataset to get a more chest X-ray variety to help us prevent overfitting and maybe achieve greater final accuracy. We'll use brightness in a range of 70% to 130%, which will darken and lighten the images.

# %%
train_image_generator = ImageDataGenerator(
                                          rescale=1./255, 
                                          brightness_range=(0.7, 1.3))  # Generator for our training data
                                          
validation_image_generator = ImageDataGenerator(rescale=1./255)  # Generator for our validation data
test_image_generator = ImageDataGenerator(rescale=1./255)  # Generator for our test data

# %% [markdown]
# The batch size specifies that we should read a 100 images at a time, then we specifies the directory of the train ou validation set to be readed. The shufle parameter when set as True, will randomize the order of the images to the model does not start to memorize the order. Since our model can only process a specific input size, we specify a target_size parameter with the width and the height to resize the images to 150 x 150. The class_mode is binary since we just have two categories: Pneumonia or Normal.

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary')
# Out:
# Found 3515 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory=val_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                              class_mode='binary')
# Out:
# Found 1170 images belonging to 2 classes.

# %%
test_data_gen = test_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=test_dir,
                                                           shuffle=False,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary')
# Out:
# Found 1171 images belonging to 2 classes.

# %% [markdown]
# ## Visualizing Training images
#
# Let's get a batch of images from the training generator to visualize a few of them using `matplotlib`.

# %%
sample_training_images, _ = next(train_data_gen)

# %% [markdown]
# The next function returns a batch from the dataset. One batch is a tuple of (many images, many labels). For right now, we're discarding the labels because we just want to look at the images.

# %%
def plotImages(images_arr, n_row, n_col):
    """
    INPUT:
    images_arr: a array of images

    DESCRIPTION:
    This function plot images in a grid with 5 row by 6 columns,
    plotting each image in a column
    """
    fig, axes = plt.subplots(n_row, n_col, figsize=(15,15))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
from random import random

visual_sample = [sample_training_images[int(random()*100)] for i in range(5)]
plotImages(visual_sample, 1, 5)

# %% [markdown]
# # Model Creation

# %% [markdown]
# ## Define the model
#
# The model consists of four convolution blocks with a max pool layer in each of them. We also use a dropout layer, which is another tecnique to help us avoid overfitting. This tecnique consists of randomly turn off some neurons as the data go through the epocs, which force other neurons to do all the job. The model will output class probabilities for two classes — Normal and Pneumonia — using softmax in the last layer.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

# %% [markdown]
# ## Compiling the model
#
# We will use the adam optimizer, and keep up with training and validation accuracy on each epoch as we train our network.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ## Model Summary
#
# Let's take a look at our model architecture!

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  dropout (Dropout)           (None, 7, 7, 128)         0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model
#
# It's time we train our network.
#
# Since our batches are coming from a generator (ImageDataGenerator), we'll use fit_generator instead of fit.

# %%
EPOCHS = 50
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE)))
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 36/36 [==============================] - 900s 25s/step - loss: 0.6227 - accuracy: 0.7058 - val_loss: 0.4953 - val_accuracy: 0.7419
# Epoch 2/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.3594 - accuracy: 0.8373 - val_loss: 0.3569 - val_accuracy: 0.8427
# Epoch 3/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.2496 - accuracy: 0.9075 - val_loss: 0.1445 - val_accuracy: 0.9427
# Epoch 4/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.1610 - accuracy: 0.9363 - val_loss: 0.1129 - val_accuracy: 0.9547
# Epoch 5/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.1612 - accuracy: 0.9394 - val_loss: 0.1190 - val_accuracy: 0.9556
# Epoch 6/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.1423 - accuracy: 0.9425 - val_loss: 0.0927 - val_accuracy: 0.9607
# Epoch 7/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.1092 - accuracy: 0.9607 - val_loss: 0.0745 - val_accuracy: 0.9701
# Epoch 8/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.1044 - accuracy: 0.9602 - val_loss: 0.0735 - val_accuracy: 0.9692
# Epoch 9/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0928 - accuracy: 0.9636 - val_loss: 0.0738 - val_accuracy: 0.9701
# Epoch 10/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0922 - accuracy: 0.9642 - val_loss: 0.0780 - val_accuracy: 0.9701
# Epoch 11/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0815 - accuracy: 0.9724 - val_loss: 0.0606 - val_accuracy: 0.9752
# Epoch 12/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0699 - accuracy: 0.9724 - val_loss: 0.0637 - val_accuracy: 0.9744
# Epoch 13/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0719 - accuracy: 0.9730 - val_loss: 0.0528 - val_accuracy: 0.9761
# Epoch 14/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0589 - accuracy: 0.9764 - val_loss: 0.0708 - val_accuracy: 0.9752
# Epoch 15/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0648 - accuracy: 0.9755 - val_loss: 0.0569 - val_accuracy: 0.9803
# Epoch 16/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0626 - accuracy: 0.9750 - val_loss: 0.0594 - val_accuracy: 0.9786
# Epoch 17/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0527 - accuracy: 0.9807 - val_loss: 0.0900 - val_accuracy: 0.9692
# Epoch 18/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0605 - accuracy: 0.9772 - val_loss: 0.0723 - val_accuracy: 0.9752
# Epoch 19/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0466 - accuracy: 0.9832 - val_loss: 0.0669 - val_accuracy: 0.9744
# Epoch 20/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0424 - accuracy: 0.9846 - val_loss: 0.0773 - val_accuracy: 0.9718
# Epoch 21/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0325 - accuracy: 0.9881 - val_loss: 0.0741 - val_accuracy: 0.9786
# Epoch 22/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0344 - accuracy: 0.9878 - val_loss: 0.0792 - val_accuracy: 0.9786
# Epoch 23/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0360 - accuracy: 0.9866 - val_loss: 0.0476 - val_accuracy: 0.9829
# Epoch 24/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0293 - accuracy: 0.9898 - val_loss: 0.0705 - val_accuracy: 0.9744
# Epoch 25/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0291 - accuracy: 0.9866 - val_loss: 0.0617 - val_accuracy: 0.9769
# Epoch 26/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0277 - accuracy: 0.9883 - val_loss: 0.0825 - val_accuracy: 0.9735
# Epoch 27/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0245 - accuracy: 0.9906 - val_loss: 0.0754 - val_accuracy: 0.9752
# Epoch 28/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0261 - accuracy: 0.9915 - val_loss: 0.0689 - val_accuracy: 0.9778
# Epoch 29/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0501 - accuracy: 0.9804 - val_loss: 0.0701 - val_accuracy: 0.9744
# Epoch 30/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0286 - accuracy: 0.9886 - val_loss: 0.0577 - val_accuracy: 0.9821
# Epoch 31/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0276 - accuracy: 0.9889 - val_loss: 0.0835 - val_accuracy: 0.9744
# Epoch 32/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0359 - accuracy: 0.9875 - val_loss: 0.0675 - val_accuracy: 0.9786
# Epoch 33/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0378 - accuracy: 0.9869 - val_loss: 0.0699 - val_accuracy: 0.9786
# Epoch 34/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0232 - accuracy: 0.9903 - val_loss: 0.0759 - val_accuracy: 0.9778
# Epoch 35/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0128 - accuracy: 0.9966 - val_loss: 0.0681 - val_accuracy: 0.9795
# Epoch 36/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0191 - accuracy: 0.9920 - val_loss: 0.0678 - val_accuracy: 0.9821
# Epoch 37/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0218 - accuracy: 0.9920 - val_loss: 0.0747 - val_accuracy: 0.9812
# Epoch 38/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0225 - accuracy: 0.9932 - val_loss: 0.0731 - val_accuracy: 0.9769
# Epoch 39/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0298 - accuracy: 0.9900 - val_loss: 0.0757 - val_accuracy: 0.9778
# Epoch 40/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0151 - accuracy: 0.9949 - val_loss: 0.0999 - val_accuracy: 0.9786
# Epoch 41/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0150 - accuracy: 0.9940 - val_loss: 0.0894 - val_accuracy: 0.9778
# Epoch 42/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0118 - accuracy: 0.9960 - val_loss: 0.0889 - val_accuracy: 0.9795
# Epoch 43/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0134 - accuracy: 0.9946 - val_loss: 0.0845 - val_accuracy: 0.9803
# Epoch 44/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.1001 - val_accuracy: 0.9812
# Epoch 45/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0909 - val_accuracy: 0.9786
# Epoch 46/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0100 - accuracy: 0.9963 - val_loss: 0.0997 - val_accuracy: 0.9812
# Epoch 47/50
# 36/36 [==============================] - 54s 2s/step - loss: 0.0091 - accuracy: 0.9966 - val_loss: 0.0919 - val_accuracy: 0.9803
# Epoch 48/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.0823 - val_accuracy: 0.9769
# Epoch 49/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0171 - accuracy: 0.9946 - val_loss: 0.0777 - val_accuracy: 0.9803
# Epoch 50/50
# 36/36 [==============================] - 55s 2s/step - loss: 0.0105 - accuracy: 0.9957 - val_loss: 0.0854 - val_accuracy: 0.9812

# %% [markdown]
# # Evaluate accuracy
#
# Next, compare how the model performs on the test dataset. Use all examples we have in the test dataset to assess accuracy.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()

# %% [markdown]
# As we can see from the plots, validation loss is increasing over epochs, which is an indication of overfitting.

# %%
import math
test_loss, test_accuracy = model.evaluate(test_data_gen, steps=math.ceil(total_test/BATCH_SIZE))
print('Accuracy on test dataset:', test_accuracy)
# Out:
# 12/12 [==============================] - 255s 23s/step - loss: 1.5961 - accuracy: 0.8779
# Accuracy on test dataset: 0.8778821229934692

# %% [markdown]
# Here we also achieved almost the same accuracy as the first trial. So, this augmentation probably doesn't help so much.

# %%
import joblib

def save_model(model, model_filepath):
    """
    INPUT
        model - a trained model
        model_filepath - a file path to store the trained model
    """
    joblib.dump(model, model_filepath)

# %%
save_model(model, 'chest-xray-classifier-IV.pkl')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
