# %% [markdown]
# # Experiment V
#
# This fifth experiment will try to increase the test accuracy and prevent overfitting apply rotation and zoom augmentation.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Importing packages
#
# Let's start by importing required packages:
#
# * os — to read files and directory structure
# * numpy — for some matrix math outside of TensorFlow
# * matplotlib.pyplot — to plot the graph and display images in our training and validation data

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# # Data Loading
#
# To build our image classifier, we begin by unzipping the dataset.

# %%
root_path = '/content/drive/MyDrive/DataSets'
os.chdir(root_path)

# %% [markdown]
# We can list the directories with the following terminal command:

# %%
dir = '/content/drive/MyDrive/DataSets/chest_xray'
zip_dir_base = os.path.dirname(dir)
# !find $zip_dir_base -type d -print
# Out:
# /content/drive/MyDrive/DataSets
# /content/drive/MyDrive/DataSets/chest_xray (1)
# /content/drive/MyDrive/DataSets/chest_xray (1)/test
# /content/drive/MyDrive/DataSets/chest_xray (1)/test/PNEUMONIA
# /content/drive/MyDrive/DataSets/chest_xray (1)/test/NORMAL
# /content/drive/MyDrive/DataSets/chest_xray (1)/train
# /content/drive/MyDrive/DataSets/chest_xray (1)/train/NORMAL
# /content/drive/MyDrive/DataSets/chest_xray (1)/train/PNEUMONIA
# /content/drive/MyDrive/DataSets/chest_xray (1)/val
# /content/drive/MyDrive/DataSets/chest_xray (1)/val/NORMAL
# /content/drive/MyDrive/DataSets/chest_xray (1)/val/PNEUMONIA
# /content/drive/MyDrive/DataSets/chest_xray
# /content/drive/MyDrive/DataSets/chest_xray/test
# /content/drive/MyDrive/DataSets/chest_xray/test/PNEUMONIA
# /content/drive/MyDrive/DataSets/chest_xray/test/NORMAL
# /content/drive/MyDrive/DataSets/chest_xray/train
# /content/drive/MyDrive/DataSets/chest_xray/train/NORMAL
# /content/drive/MyDrive/DataSets/chest_xray/train/PNEUMONIA
# /content/drive/MyDrive/DataSets/chest_xray/val
# /content/drive/MyDrive/DataSets/chest_xray/val/NORMAL
# /content/drive/MyDrive/DataSets/chest_xray/val/PNEUMONIA
# /content/drive/MyDrive/DataSets/__MACOSX
# /content/drive/MyDrive/DataSets/__MACOSX/chest_xray
# /content/drive/MyDrive/DataSets/__MACOSX/chest_xray/test
# /content/drive/MyDrive/DataSets/__MACOSX/chest_xray/test/PNEUMONIA
# /content/drive/MyDrive/DataSets/__MACOSX/chest_xray/train
# /content/drive/MyDrive/DataSets/__MACOSX/chest_xray/train/PNEUMONIA
# /content/drive/MyDrive/DataSets/__MACOSX/chest_xray/train/NORMAL

# %% [markdown]
# We'll now assign variables with the proper file path for the training and test sets.

# %%
base_dir = os.path.join(os.path.dirname(dir), 'chest_xray')
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')
val_dir = os.path.join(base_dir, 'val')

# %% [markdown]
# Let's look at how many normal and pneumonia images we have in our training, validation and test directory.

# %%
def get_total_chest_xray(category, source):
  """
  INPUT
  category: data set category, which could be 'training', 'test' and 'validation'
  source: a directory path.

  OUTPUT
  num_normal: total number of pictures
  num_pneumonia: 
  total: 

  DESCRIPTION
  This function move X (amount) random pictures from a source folder
  to destination folder.
  """
  source_normal = os.path.join(source, 'NORMAL') 
  source_pneumonia = os.path.join(source, 'PNEUMONIA')

  num_normal = len(os.listdir(source_normal))
  num_pneumonia = len(os.listdir(source_pneumonia))
  total = num_normal + num_pneumonia

  print('Total {}: {}'.format(category, total))
  print('total {} normal images: {}'.format(category, num_normal))
  print('total {} pneumonia images: {}'.format(category, num_pneumonia))

  return num_normal, num_pneumonia, total

# %%
num_normal_tr, num_pneumonia_tr, total_train = get_total_chest_xray('training', train_dir)
# Out:
# Total training: 3515
# total training normal images: 979
# total training pneumonia images: 2536

# %%
num_normal_test, num_pneumonia_test, total_test = get_total_chest_xray('test', test_dir)
# Out:
# Total test: 1171
# total test normal images: 302
# total test pneumonia images: 869

# %%
num_normal_val, num_pneumonia_val, total_val = get_total_chest_xray('validation', val_dir)
# Out:
# Total validation: 1171
# total validation normal images: 302
# total validation pneumonia images: 869

# %% [markdown]
# ## Setting Model Parameters
#
# Let's specify some model parameters.

# %%
BATCH_SIZE = 100  # Specifies how many training examples we feed our model before we update it's weight and bias variables
IMG_SHAPE  = 150  # Specifies the width and height in pixels to help the model process the images using a single input size

# %% [markdown]
# # Data Augmentation
#
#
# We will apply rotation to our training set to augment the dataset to get a more chest X-ray variety to help us prevent overfitting and maybe achieve greater final accuracy. We'll use brightness in a range of 70% to 130%, which will darken and lighten the images.

# %%
train_image_generator = ImageDataGenerator(
                                          rescale=1./255,
                                          rotation_range=20,
                                          zoom_range=0.3)  # Generator for our training data
                                          
validation_image_generator = ImageDataGenerator(rescale=1./255)  # Generator for our validation data
test_image_generator = ImageDataGenerator(rescale=1./255)  # Generator for our test data

# %% [markdown]
# The batch size specifies that we should read a 100 images at a time, then we specifies the directory of the train ou validation set to be readed. The shufle parameter when set as True, will randomize the order of the images to the model does not start to memorize the order. Since our model can only process a specific input size, we specify a target_size parameter with the width and the height to resize the images to 150 x 150. The class_mode is binary since we just have two categories: Pneumonia or Normal.

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary')
# Out:
# Found 3515 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory=val_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                              class_mode='binary')
# Out:
# Found 1170 images belonging to 2 classes.

# %%
test_data_gen = test_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=test_dir,
                                                           shuffle=False,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary')
# Out:
# Found 1171 images belonging to 2 classes.

# %% [markdown]
# ## Visualizing Training images
#
# Let's get a batch of images from the training generator to visualize a few of them using `matplotlib`.

# %%
sample_training_images, _ = next(train_data_gen)

# %% [markdown]
# The next function returns a batch from the dataset. One batch is a tuple of (many images, many labels). For right now, we're discarding the labels because we just want to look at the images.

# %%
def plotImages(images_arr, n_row, n_col):
    """
    INPUT:
    images_arr: a array of images

    DESCRIPTION:
    This function plot images in a grid with 5 row by 6 columns,
    plotting each image in a column
    """
    fig, axes = plt.subplots(n_row, n_col, figsize=(15,15))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
from random import random

visual_sample = [sample_training_images[int(random()*100)] for i in range(36)]
plotImages(visual_sample, 6, 6)

# %% [markdown]
# # Model Creation

# %% [markdown]
# ## Define the model
#
# The model consists of four convolution blocks with a max pool layer in each of them. We also use a dropout layer, which is another tecnique to help us avoid overfitting. This tecnique consists of randomly turn off some neurons as the data go through the epocs, which force other neurons to do all the job. The model will output class probabilities for two classes — Normal and Pneumonia — using softmax in the last layer.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

# %% [markdown]
# ## Compiling the model
#
# We will use the adam optimizer, and keep up with training and validation accuracy on each epoch as we train our network.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ## Model Summary
#
# Let's take a look at our model architecture!

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_4 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_7 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 128)         0
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_2 (Dense)             (None, 512)               3211776
#
#  dense_3 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model
#
# It's time we train our network.
#
# Since our batches are coming from a generator (ImageDataGenerator), we'll use fit_generator instead of fit.

# %%
EPOCHS = 80
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE)))
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/80
# 36/36 [==============================] - 239s 7s/step - loss: 0.6276 - accuracy: 0.6933 - val_loss: 0.5346 - val_accuracy: 0.7419
# Epoch 2/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.4519 - accuracy: 0.7886 - val_loss: 0.3983 - val_accuracy: 0.8128
# Epoch 3/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.3443 - accuracy: 0.8509 - val_loss: 0.3711 - val_accuracy: 0.8282
# Epoch 4/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.2780 - accuracy: 0.8797 - val_loss: 0.2111 - val_accuracy: 0.9214
# Epoch 5/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.2710 - accuracy: 0.8771 - val_loss: 0.2750 - val_accuracy: 0.8752
# Epoch 6/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.2587 - accuracy: 0.8927 - val_loss: 0.2648 - val_accuracy: 0.8812
# Epoch 7/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.2352 - accuracy: 0.9061 - val_loss: 0.1689 - val_accuracy: 0.9342
# Epoch 8/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.2549 - accuracy: 0.8933 - val_loss: 0.2352 - val_accuracy: 0.9017
# Epoch 9/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.2182 - accuracy: 0.9112 - val_loss: 0.2406 - val_accuracy: 0.8915
# Epoch 10/80
# 36/36 [==============================] - 66s 2s/step - loss: 0.2147 - accuracy: 0.9078 - val_loss: 0.1551 - val_accuracy: 0.9410
# Epoch 11/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.2043 - accuracy: 0.9181 - val_loss: 0.1623 - val_accuracy: 0.9333
# Epoch 12/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.2087 - accuracy: 0.9201 - val_loss: 0.1737 - val_accuracy: 0.9256
# Epoch 13/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.2239 - accuracy: 0.9075 - val_loss: 0.1704 - val_accuracy: 0.9342
# Epoch 14/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1978 - accuracy: 0.9195 - val_loss: 0.1681 - val_accuracy: 0.9368
# Epoch 15/80
# 36/36 [==============================] - 66s 2s/step - loss: 0.1891 - accuracy: 0.9257 - val_loss: 0.1470 - val_accuracy: 0.9556
# Epoch 16/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1987 - accuracy: 0.9178 - val_loss: 0.2188 - val_accuracy: 0.9085
# Epoch 17/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1820 - accuracy: 0.9266 - val_loss: 0.1665 - val_accuracy: 0.9368
# Epoch 18/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1736 - accuracy: 0.9331 - val_loss: 0.1551 - val_accuracy: 0.9470
# Epoch 19/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1803 - accuracy: 0.9306 - val_loss: 0.1566 - val_accuracy: 0.9402
# Epoch 20/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1513 - accuracy: 0.9431 - val_loss: 0.1522 - val_accuracy: 0.9462
# Epoch 21/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1662 - accuracy: 0.9357 - val_loss: 0.1591 - val_accuracy: 0.9333
# Epoch 22/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1622 - accuracy: 0.9420 - val_loss: 0.1881 - val_accuracy: 0.9231
# Epoch 23/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1549 - accuracy: 0.9385 - val_loss: 0.2201 - val_accuracy: 0.9103
# Epoch 24/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1656 - accuracy: 0.9377 - val_loss: 0.1319 - val_accuracy: 0.9538
# Epoch 25/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1555 - accuracy: 0.9408 - val_loss: 0.1802 - val_accuracy: 0.9308
# Epoch 26/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1452 - accuracy: 0.9471 - val_loss: 0.1472 - val_accuracy: 0.9410
# Epoch 27/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1514 - accuracy: 0.9434 - val_loss: 0.1224 - val_accuracy: 0.9547
# Epoch 28/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1392 - accuracy: 0.9451 - val_loss: 0.1370 - val_accuracy: 0.9444
# Epoch 29/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1340 - accuracy: 0.9445 - val_loss: 0.2116 - val_accuracy: 0.9171
# Epoch 30/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1461 - accuracy: 0.9445 - val_loss: 0.1193 - val_accuracy: 0.9564
# Epoch 31/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1180 - accuracy: 0.9570 - val_loss: 0.1180 - val_accuracy: 0.9556
# Epoch 32/80
# 36/36 [==============================] - 64s 2s/step - loss: 0.1260 - accuracy: 0.9494 - val_loss: 0.1466 - val_accuracy: 0.9470
# Epoch 33/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1336 - accuracy: 0.9545 - val_loss: 0.1542 - val_accuracy: 0.9368
# Epoch 34/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1293 - accuracy: 0.9494 - val_loss: 0.1451 - val_accuracy: 0.9436
# Epoch 35/80
# 36/36 [==============================] - 64s 2s/step - loss: 0.1217 - accuracy: 0.9539 - val_loss: 0.1485 - val_accuracy: 0.9419
# Epoch 36/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1270 - accuracy: 0.9496 - val_loss: 0.1383 - val_accuracy: 0.9470
# Epoch 37/80
# 36/36 [==============================] - 64s 2s/step - loss: 0.1295 - accuracy: 0.9505 - val_loss: 0.1339 - val_accuracy: 0.9462
# Epoch 38/80
# 36/36 [==============================] - 64s 2s/step - loss: 0.1366 - accuracy: 0.9471 - val_loss: 0.1545 - val_accuracy: 0.9530
# Epoch 39/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1318 - accuracy: 0.9519 - val_loss: 0.1364 - val_accuracy: 0.9444
# Epoch 40/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1239 - accuracy: 0.9525 - val_loss: 0.1251 - val_accuracy: 0.9556
# Epoch 41/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1212 - accuracy: 0.9542 - val_loss: 0.1185 - val_accuracy: 0.9530
# Epoch 42/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1183 - accuracy: 0.9568 - val_loss: 0.1461 - val_accuracy: 0.9427
# Epoch 43/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1105 - accuracy: 0.9596 - val_loss: 0.1378 - val_accuracy: 0.9462
# Epoch 44/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1125 - accuracy: 0.9607 - val_loss: 0.1260 - val_accuracy: 0.9479
# Epoch 45/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1219 - accuracy: 0.9508 - val_loss: 0.1304 - val_accuracy: 0.9453
# Epoch 46/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1052 - accuracy: 0.9639 - val_loss: 0.1497 - val_accuracy: 0.9419
# Epoch 47/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1191 - accuracy: 0.9553 - val_loss: 0.1521 - val_accuracy: 0.9419
# Epoch 48/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1255 - accuracy: 0.9508 - val_loss: 0.1953 - val_accuracy: 0.9265
# Epoch 49/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1209 - accuracy: 0.9536 - val_loss: 0.1253 - val_accuracy: 0.9479
# Epoch 50/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1076 - accuracy: 0.9610 - val_loss: 0.1303 - val_accuracy: 0.9479
# Epoch 51/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1107 - accuracy: 0.9542 - val_loss: 0.1316 - val_accuracy: 0.9453
# Epoch 52/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1107 - accuracy: 0.9565 - val_loss: 0.1279 - val_accuracy: 0.9487
# Epoch 53/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1078 - accuracy: 0.9622 - val_loss: 0.1613 - val_accuracy: 0.9376
# Epoch 54/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1073 - accuracy: 0.9576 - val_loss: 0.1340 - val_accuracy: 0.9453
# Epoch 55/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1058 - accuracy: 0.9596 - val_loss: 0.1322 - val_accuracy: 0.9530
# Epoch 56/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1120 - accuracy: 0.9568 - val_loss: 0.1188 - val_accuracy: 0.9521
# Epoch 57/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1237 - accuracy: 0.9539 - val_loss: 0.1691 - val_accuracy: 0.9393
# Epoch 58/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1075 - accuracy: 0.9593 - val_loss: 0.1141 - val_accuracy: 0.9538
# Epoch 59/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.0931 - accuracy: 0.9613 - val_loss: 0.1803 - val_accuracy: 0.9274
# Epoch 60/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.0870 - accuracy: 0.9681 - val_loss: 0.1146 - val_accuracy: 0.9513
# Epoch 61/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.0870 - accuracy: 0.9656 - val_loss: 0.1142 - val_accuracy: 0.9547
# Epoch 62/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1189 - accuracy: 0.9531 - val_loss: 0.2519 - val_accuracy: 0.9214
# Epoch 63/80
# 36/36 [==============================] - 66s 2s/step - loss: 0.1057 - accuracy: 0.9582 - val_loss: 0.1379 - val_accuracy: 0.9479
# Epoch 64/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.1030 - accuracy: 0.9622 - val_loss: 0.1628 - val_accuracy: 0.9359
# Epoch 65/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.0960 - accuracy: 0.9653 - val_loss: 0.1572 - val_accuracy: 0.9410
# Epoch 66/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.0909 - accuracy: 0.9690 - val_loss: 0.1703 - val_accuracy: 0.9385
# Epoch 67/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.0906 - accuracy: 0.9664 - val_loss: 0.1105 - val_accuracy: 0.9564
# Epoch 68/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.0981 - accuracy: 0.9656 - val_loss: 0.1735 - val_accuracy: 0.9350
# Epoch 69/80
# 36/36 [==============================] - 66s 2s/step - loss: 0.0981 - accuracy: 0.9610 - val_loss: 0.1133 - val_accuracy: 0.9496
# Epoch 70/80
# 36/36 [==============================] - 66s 2s/step - loss: 0.0969 - accuracy: 0.9636 - val_loss: 0.1756 - val_accuracy: 0.9393
# Epoch 71/80
# 36/36 [==============================] - 66s 2s/step - loss: 0.0841 - accuracy: 0.9698 - val_loss: 0.1366 - val_accuracy: 0.9479
# Epoch 72/80
# 36/36 [==============================] - 66s 2s/step - loss: 0.0844 - accuracy: 0.9681 - val_loss: 0.1405 - val_accuracy: 0.9487
# Epoch 73/80
# 36/36 [==============================] - 66s 2s/step - loss: 0.0858 - accuracy: 0.9676 - val_loss: 0.1941 - val_accuracy: 0.9385
# Epoch 74/80
# 36/36 [==============================] - 66s 2s/step - loss: 0.0914 - accuracy: 0.9661 - val_loss: 0.1840 - val_accuracy: 0.9342
# Epoch 75/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.0956 - accuracy: 0.9616 - val_loss: 0.1432 - val_accuracy: 0.9419
# Epoch 76/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.0912 - accuracy: 0.9639 - val_loss: 0.1358 - val_accuracy: 0.9547
# Epoch 77/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.0950 - accuracy: 0.9627 - val_loss: 0.1203 - val_accuracy: 0.9556
# Epoch 78/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.0814 - accuracy: 0.9724 - val_loss: 0.1202 - val_accuracy: 0.9556
# Epoch 79/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.0834 - accuracy: 0.9684 - val_loss: 0.1837 - val_accuracy: 0.9359
# Epoch 80/80
# 36/36 [==============================] - 65s 2s/step - loss: 0.0982 - accuracy: 0.9624 - val_loss: 0.1032 - val_accuracy: 0.9624

# %% [markdown]
# # Evaluate accuracy
#
# Next, compare how the model performs on the test dataset. Use all examples we have in the test dataset to assess accuracy.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()

# %% [markdown]
# As we can see from the plots, training accuracy and validation accuracy are very close, which is a indication that the model is not overfitting, and model has achieved around 97% accuracy on the validation set (depending on the number of epochs you trained for).

# %%
import math
test_loss, test_accuracy = model.evaluate(test_data_gen, steps=math.ceil(total_test/BATCH_SIZE))
print('Accuracy on test dataset:', test_accuracy)
# Out:
# 12/12 [==============================] - 247s 22s/step - loss: 0.1721 - accuracy: 0.9505
# Accuracy on test dataset: 0.9504696726799011

# %% [markdown]
# As it turns out, the accuracy on the test dataset is smaller than the accuracy on the training dataset. This is completely normal, since the model was trained on the train_dataset. When the model sees images it has never seen during training, (that is, from the test_dataset), we can expect performance to go down.

# %%
import joblib

def save_model(model, model_filepath):
    """
    INPUT
        model - a trained model
        model_filepath - a file path to store the trained model
    """
    joblib.dump(model, model_filepath)

# %%
save_model(model, 'chest-xray-classifier-V.pkl')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
